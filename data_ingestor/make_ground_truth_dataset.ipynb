# %%
import pandas as pd

df = pd.read_csv("replications_database_2025_11_11_180242.csv")

df.columns
# Out:
# Index(['original_url', 'replication_url', 'description', 'result',
#        'original_authors', 'original_title', 'original_journal',
#        'original_volume', 'original_issue', 'original_pages', 'original_year',
#        'replication_authors', 'replication_title', 'replication_journal',
#        'replication_volume', 'replication_issue', 'replication_pages',
#        'replication_year', 'original_n', 'original_es', 'original_es_type',
#        'original_es_95_CI', 'original_p_value', 'original_p_value_type',
#        'original_p_value_tails', 'replication_n', 'replication_es',
#        'replication_es_type', 'replication_es_95_CI', 'replication_p_value',
#        'replication_p_value_type', 'replication_p_value_tails', 'discipline',
#        'tags', 'validated', 'validated_person', 'openalex_field',
#        'openalex_subfield', 'replication_citation_html',
#        'original_citation_html', 'Unnamed: 0', 'original_es_r',
#        'replication_es_r'],
#       dtype='object')

# %%
len(set(df['original_url'].values)) + len(set(df['replication_url'].values))
# Out:
# 905

# %%
import os
import pandas as pd

df = pd.read_csv("replications_database_2025_11_11_180242.csv")

save_dir = "/home/dan/Dropbox/AAA_METASCIENCE_OBSERVATORY/PDFs/in_ground_truth_dataset/"

# ---------------------------------------------------
# Helpers
# ---------------------------------------------------

def extract_doi(url: str) -> str | None:
    """Extract and normalize DOI from an original/replication URL."""
    if not isinstance(url, str) or not url.strip():
        return None

    url = url.strip()

    # Only accept URLs that actually contain doi.org
    if "doi.org/" not in url.lower():
        return None

    doi = (
        url.replace("https://doi.org/", "")
           .replace("http://doi.org/", "")
           .strip()
           .lower()
    )

    return doi if doi else None


def pdf_path_from_doi(doi: str) -> str:
    """Map normalized DOI to expected PDF path."""
    safe_filename = doi.replace("/", "--") + ".pdf"
    return os.path.join(save_dir, safe_filename)


def pdf_exists_for_url(url: str) -> bool:
    """Check if PDF for this URL exists."""
    doi = extract_doi(url)
    if not doi:
        return False

    path = pdf_path_from_doi(doi)
    return os.path.exists(path)


# ---------------------------------------------------
# Apply checks to dataframe
# ---------------------------------------------------

# Boolean columns showing whether the PDFs exist
df["original_pdf_exists"] = df["original_url"].apply(pdf_exists_for_url)
df["replication_pdf_exists"] = df["replication_url"].apply(pdf_exists_for_url)

# Filter to keep only rows where BOTH PDFs exist
filtered_df = df[df["original_pdf_exists"] & df["replication_pdf_exists"]].copy()

# Optional: drop helper columns
filtered_df = filtered_df.drop(columns=["original_pdf_exists", "replication_pdf_exists"])

print("Rows originally:", len(df))
print("Rows after filtering:", len(filtered_df))

# Save if you want
# filtered_df.to_csv("replications_with_pdfs_only.csv", index=False)
# Out:
# Rows originally: 872
# Rows after filtering: 672

# %%
df["original_es_r"] = pd.to_numeric(df["original_es_r"], errors="coerce")
df["replication_es_r"] = pd.to_numeric(df["replication_es_r"], errors="coerce")
df = df[df["original_es_r"].notna() & df["replication_es_r"].notna()]

# %%
df.to_csv("ground_truth.csv")

# %%
len(df)
# Out:
# 438

# %%
df
# Out:
#                                           original_url  \
# 791            http://doi.org/10.1177/0956797612447820
# 792            http://doi.org/10.1177/0956797612447820
# 862  https://scholar.google.com/scholar?cluster=333...
# 863        http://doi.org/10.1037/0022-3514.37.10.1660
# 865         http://doi.org/10.14695/kjsos.2015.18.4.15
# 866               http://doi.org/10.1509/jmkr.45.6.633
# 867   https://doi.org/10.1111/j.1467-9280.2008.02084.x
# 868            http://doi.org/10.1177/0956797611414726
# 869   https://doi.org/10.1111/j.1467-9280.2008.02062.x
# 870                    http://doi.org/10.1037/a0029288
# 871          http://doi.org/10.1037/0022-3514.82.6.956
#
#                                        replication_url  \
# 791  https://web.archive.org/web/20200206205411/htt...
# 792  https://web.archive.org/web/20200206205411/htt...
# 862       https://doi.org/10.1371/journal.pone.0029081
# 863            http://doi.org/10.1177/2515245918777487
# 865           http://doi.org/10.1027/1864-9335/a000186
# 866            http://doi.org/10.1177/2515245918781032
# 867       https://doi.org/10.1371/journal.pone.0042510
# 868  https://psycnet.apa.org/fulltext/2014-20922-00...
# 869               http://doi.org/10.31234/osf.io/ux8ef
# 870                  http://doi.org/10.1037/xge0000570
# 871            http://doi.org/10.1177/1745691616664694
#
#                                            description        result  \
# 791  Liberal participants rated liberal groups more...       success
# 792  Conservative rated conservative groups more po...           NaN
# 862     Hearing about old age makes people walk slower       failure
# 863  The paper demonstrated that the ease with whic...       failure
# 865  Participants who cleansed their hands before j...       failure
# 866  When participants had more opportunity to chea...       failure
# 867  Priming people with cues of physical spatial d...       failure
# 868  Exposure to the American Shifts Support Toward...  inconclusive
# 869  When people process stimuli with low fluency (...       failure
# 870  Mere exposure to money increases endorsement o...       failure
# 871  There is a causal link between subjective comm...       failure
#
#                                       original_authors  \
# 791    Chambers, J. R., Schlenker, B. R.; Collisson, B
# 792  John R. Chambers; Barry R. Schlenker; Brian Co...
# 862  Luca Giancardo; Diego Sona; Huiping Huang; Sar...
# 863                    Thomas K. Srull; Robert S. Wyer
# 865    David J. Johnson; Felix Cheung; Brent Donnellan
# 866                    Nina Mažar; On Amir; Dan Ariely
# 867                Lawrence E. Williams; John A. Bargh
# 868  Travis J. Carter; Melissa J. Ferguson; Ran R. ...
# 869               Adam L. Alter; Daniel M. Oppenheimer
# 870  Eugene M. Caruso; Kathleen D. Vohs; Brittani B...
# 871  Eli J. Finkel; Caryl E. Rusbult; Madoka Kumash...
#
#                                         original_title  \
# 791  Ideology and Prejudice The Role of Value Confl...
# 792                             Ideology and Prejudice
# 862                   Automaticity of social behaviour
# 863  The role of category accessibility in the inte...
# 865  Cleanliness Reduces the Severity of\nMoral Jud...
# 866  The Dishonesty of Honest People: A Theory of S...
# 867                             Keeping One's Distance
# 868  A Single Exposure to the American Flag Shifts ...
# 869  Effects of Fluency on Psychological Distance a...
# 870  Mere exposure to money increases endorsement o...
# 871  Dealing with betrayal in close relationships: ...
#
#                                  original_journal  original_volume  \
# 791                         Psychological Science             24.0
# 792                         Psychological Science             24.0
# 862                                      PLoS ONE              8.0
# 863  Journal of Personality and Social Psychology             37.0
# 865    Korean Society for Emotion and Sensibility             18.0
# 866                 Journal of Marketing Research             45.0
# 867                         Psychological Science             19.0
# 868                            Psychology Science             22.0
# 869                         Psychological Science             19.0
# 870   Journal of Experimental Psychology: General            142.0
# 871  Journal of Personality and Social Psychology             82.0
#
#     original_issue original_pages  ...                  tags validated  \
# 791            2.0            140  ...  Political psychology       yes
# 792            2.0            140  ...  Political psychology       yes
# 862              9         e74557  ...                   NaN       yes
# 863             10           1660  ...                   NaN       yes
# 865              4          15-24  ...               priming       yes
# 866              6            633  ...                   NaN       yes
# 867              3            302  ...                   NaN       yes
# 868              8           1011  ...                   NaN       yes
# 869              2            161  ...                   NaN       yes
# 870              2            301  ...                   NaN       yes
# 871              6            956  ...                   NaN       yes
#
#     validated_person openalex_field  openalex_subfield  \
# 791        Dan Elton            NaN                NaN
# 792        Dan Elton            NaN                NaN
# 862        Dan Elton            NaN                NaN
# 863        Dan Elton            NaN                NaN
# 865        Dan Elton            NaN                NaN
# 866        Dan Elton            NaN                NaN
# 867        Dan Elton            NaN                NaN
# 868        Dan Elton            NaN                NaN
# 869        Dan Elton            NaN                NaN
# 870        Dan Elton            NaN                NaN
# 871        Dan Elton            NaN                NaN
#
#                              replication_citation_html  \
# 791                                       <i></i> 2013
# 792                                            <i></i>
# 862  <a href="https://doi.org/10.1371/journal.pone....
# 863  <a href="https://doi.org/10.1177/2515245918777...
# 865  <a href="https://doi.org/10.1027/1864-9335/a00...
# 866  <a href="https://doi.org/10.1177/2515245918781...
# 867  <a href="https://doi.org/10.1371/journal.pone....
# 868  2014 K. <i>et al.</i> <i>Advances in Methods a...
# 869  <a href="https://doi.org/10.31234/osf.io/ux8ef...
# 870  <a href="https://doi.org/10.1037/xge0000570" t...
# 871  <a href="https://doi.org/10.1177/1745691616664...
#
#                                 original_citation_html  Unnamed: 0  \
# 791  <a href="https://doi.org/10.1177/0956797612447...         NaN
# 792  <a href="https://doi.org/10.1177/0956797612447...         NaN
# 862    Giancardo L. <i>et al.</i> <i>PLoS ONE</i> 2013         NaN
# 863  <a href="https://doi.org/10.1037/0022-3514.37....         NaN
# 865  <a href="https://doi.org/10.14695/kjsos.2015.1...         NaN
# 866  <a href="https://doi.org/10.1509/jmkr.45.6.633...         NaN
# 867  <a href="https://doi.org/10.1111/j.1467-9280.2...         NaN
# 868  <a href="https://doi.org/10.1177/0956797611414...         NaN
# 869  <a href="https://doi.org/10.1111/j.1467-9280.2...         NaN
# 870  <a href="https://doi.org/10.1037/a0029288" tar...         NaN
# 871  <a href="https://doi.org/10.1037/0022-3514.82....         NaN
#
#      original_es_r  replication_es_r
# 791            NaN               NaN
# 792            NaN               NaN
# 862            NaN               NaN
# 863            NaN               NaN
# 865            NaN               NaN
# 866            NaN               NaN
# 867            NaN               NaN
# 868            NaN               NaN
# 869            NaN               NaN
# 870            NaN               NaN
# 871            NaN               NaN
#
# [11 rows x 43 columns]
